# %% [markdown]
# # Track Data Enriching
#
# **Main objective:** include the `main genre` of the *artist* and `album image URI` in the dataset, expanding the analysis possibilities. Also, the `platform` column is normalized, and the complete information removed from the dataset for privacy and security reasons.
#
# To do the *data enriching* steps, I used the [Spotipy](https://github.com/spotipy-dev/spotipy) library to make the interface with [Spotify's Web API](https://developer.spotify.com/documentation/web-api).
#
# Regarding the data, I used the **Extended streaming history** download, that can be found under *Privacy* settings on your Spotify account. For more information on how to get yours, here is a [simple tutorial from Quora](https://www.quora.com/How-can-I-download-my-Spotify-data).
#
# *Disclaimer*: this is my own data, thus, my own music taste and Spotify usage. I am not responsible if your musical taste is not as good as mine 😂

# %% [markdown]
# ## Imports and inicializations

# %%
import pandas as pd
import spotipy
import time

from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
sp

# %%
tracks_history = pd.read_csv('consolidated_spotify_data_2024.csv')
tracks_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189780 entries, 0 to 189779
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   timestamp_play     189780 non-null  object
#  1   platform           189780 non-null  object
#  2   ms_played          189780 non-null  int64
#  3   track_name         189780 non-null  object
#  4   artist_name        189780 non-null  object
#  5   album_name         189780 non-null  object
#  6   spotify_track_uri  189780 non-null  object
#  7   reason_start       189713 non-null  object
#  8   reason_end         151097 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 13.0+ MB

# %%
tracks_history.head(5)
# Out:
#          timestamp_play                                 platform  ms_played  \
# 0  2022-01-22T12:59:36Z  Android OS 11 API 30 (Xiaomi, M2101K6G)       2567
# 1  2022-01-22T13:00:24Z  Android OS 11 API 30 (Xiaomi, M2101K6G)      47653
# 2  2022-01-22T13:04:16Z  Android OS 11 API 30 (Xiaomi, M2101K6G)     218223
# 3  2022-01-22T13:05:17Z  Android OS 11 API 30 (Xiaomi, M2101K6G)      61025
# 4  2022-01-22T13:05:41Z  Android OS 11 API 30 (Xiaomi, M2101K6G)      23375
#
#              track_name      artist_name                          album_name  \
# 0                GALOPA    PEDRO SAMPAIO                              GALOPA
# 1               A QUEDA    Gloria Groove                             A QUEDA
# 2  Convite de Casamento     Luan Santana  Confraternização Família Santana 2
# 3    Acordando o Prédio     Luan Santana                  Acordando o Prédio
# 4                Juntos  Paula Fernandes                              Juntos
#
#                       spotify_track_uri reason_start reason_end
# 0  spotify:track:2wG1R0uDFwyobcWzVssC1J     clickrow    endplay
# 1  spotify:track:2s9BO8c0co0PmgBiUoTT17     clickrow    endplay
# 2  spotify:track:3BDnZJC9yaj01jtqpyDYzG     clickrow    endplay
# 3  spotify:track:40bK2uosUmAS92c17n98xd     clickrow    endplay
# 4  spotify:track:2PIWldP9oUhb9iqe3EJh1e     clickrow    endplay

# %% [markdown]
# ## Data Enriching
#
# There is some interesting facts about this part, as I am filling the notebook after completing the development:
#
# I found out, in the worst way, that APIs have *request rate limits*. This is, on the first try, I sent around 4k requests to **Spotify's API**, what is impractical and could get my API access cut (luckily, this did not happen).
#
# **Datasets are unique**, so knowing its *structure and context* is fundamental. This is a **expanded tracks history**, and knowing my own musical habits, I know that most tracks here were played hundreds of times during the last 10 years (focus on Linkin Park and Green Day). It is, instead of sending a request for each track in the list (182k) multiple times, I can unify them and send only one request per track. Of course, it probably is still a big number, but already better than the initial one.

# %%
unique_artists = tracks_history.groupby('artist_name')[['spotify_track_uri']].first().reset_index()
print('Artists:', len(unique_artists))
unique_artists.sample(10)
# Out:
# Artists: 9480
#             artist_name                     spotify_track_uri
# 4355          Kilavista  spotify:track:436tA4Teo7CPNadBzUihMV
# 7348             Sickly  spotify:track:7GXO38sbsOtZcL4C2HCEMa
# 1537               Chon  spotify:track:2FDSwTY9PHc5dS8jWzXUq0
# 5442      Melvin Taylor  spotify:track:1pXIOp6Vl3QMvvIPFCjj2s
# 8562          Toploader  spotify:track:1FHNctV68GUNLgXclG2DtR
# 2682               F4ST  spotify:track:7tNAeLkrsnOqKXWTmd8cQp
# 2507           Elephanz  spotify:track:6gj7kH97i7Iy1JQWXk7vS8
# 4021   Joker & Sequence  spotify:track:2SBahFRVnfbLkhaP7SsSTN
# 2980                GNR  spotify:track:1nnFZioZrw6CRfiUk8KIEE
# 4855  Luciano Pavarotti  spotify:track:3KEx71XWs0qpcqChWzhRyn

# %% [markdown]
# Now, instead of sending a request for each track as I first tried with the [Get Track endpoint](https://developer.spotify.com/documentation/web-api/reference/get-track), I discovered I can actually send a batch of `track_id` and [Get Several Tracks](https://developer.spotify.com/documentation/web-api/reference/get-several-tracks) at once. *Isn't this beautiful?*
#
# [Spotify's documentation](https://developer.spotify.com/documentation/web-api/reference/get-several-tracks) says it has a limit of 100 IDs per request. But, [Spotipy's documentation](https://spotipy.readthedocs.io/en/2.16.1/#spotipy.client.Spotify.tracks) says it has a 50 IDs limitation. I tried both, but only 50 worked, so let's stay under this limit.
#
# Now, having the `batch_size` defined, it was needed to create the batches for further usage.

# %%
unique_tracks = tracks_history[['spotify_track_uri']].drop_duplicates()
unique_tracks_ids = unique_tracks['spotify_track_uri'].tolist()

# Spotipy's documentation says the limit is 50 IDs
batch_size = 50

track_uris_batches = []
for i in range(0, len(unique_tracks_ids), batch_size):
    track_uris_batches.append(unique_tracks_ids[i:i+batch_size])

print('Batches:', len(track_uris_batches))
# Out:
# Batches: 690

# %% [markdown]
# Here is the logic to get the information needed. First, we take each *batch* and make an API request. With the *response tracks* in hand, we can go through each track and then extract the information intended.
#
# 1. **Album cover URI:** this is already included in the *track* JSON. As Spotify's response include several URIs related to different sizes and qualities, we just want to get the first one, that should be the smallest one available (if included).
#
# 2. **Artist:** unfortunately, the *artist's genre* is not included in the *track* JSON. We only have access to *artist's ID* here, so this will be used later to make another request.
#
# Just as I mentioned before, Spotify's API has a rate limit based on a 30-seconds window. I was not able to find exactly how much is this limit, but I thought it was a good idea to keep my requests under 4 per second (or one each 250ms). That is why I added a `request_delay` variable that controls the `time.sleep` function after each request.

# %%
tracks_enriched = []
counter = 0
request_delay = 0.25 # Delay (in seconds) between requests to avoid API rate limitation

for batch in track_uris_batches:
    tracks = sp.tracks(batch)['tracks']
    
    for track in tracks:
        artist_id = track['artists'][0]['id']
        album = track['album']

        # Get album cover URL from the smallest available image size
        album_cover_url = album['images'][0]['url'] if album['images'] else None
        
        tracks_enriched.append({
            'spotify_track_uri': track['uri'],
            'track_id': track['id'],
            'artist_id': artist_id,
            'album_cover_url': album_cover_url
        })
        
    # Counting and printing for progress tracking
    counter += 1
    
    if counter % 10 == 0:
        print(f'Progress: {counter} out of {len(track_uris_batches)} ({int(counter / len(track_uris_batches) * 100)}%)')
    
    time.sleep(request_delay)

print(f'Processed a total of {counter} batches.')
# Out:
# Progress: 10 out of 690 (1%)
# Progress: 20 out of 690 (2%)
# Progress: 30 out of 690 (4%)
# Progress: 40 out of 690 (5%)
# Progress: 50 out of 690 (7%)
# Progress: 60 out of 690 (8%)
# Progress: 70 out of 690 (10%)
# Progress: 80 out of 690 (11%)
# Progress: 90 out of 690 (13%)
# Progress: 100 out of 690 (14%)
# Progress: 110 out of 690 (15%)
# Progress: 120 out of 690 (17%)
# Progress: 130 out of 690 (18%)
# Progress: 140 out of 690 (20%)
# Progress: 150 out of 690 (21%)
# Progress: 160 out of 690 (23%)
# Progress: 170 out of 690 (24%)
# Progress: 180 out of 690 (26%)
# Progress: 190 out of 690 (27%)
# Progress: 200 out of 690 (28%)
# Progress: 210 out of 690 (30%)
# Progress: 220 out of 690 (31%)
# Progress: 230 out of 690 (33%)
# Progress: 240 out of 690 (34%)
# Progress: 250 out of 690 (36%)
# Progress: 260 out of 690 (37%)
# Progress: 270 out of 690 (39%)
# Progress: 280 out of 690 (40%)
# Progress: 290 out of 690 (42%)
# Progress: 300 out of 690 (43%)
# Progress: 310 out of 690 (44%)
# Progress: 320 out of 690 (46%)
# Progress: 330 out of 690 (47%)
# Progress: 340 out of 690 (49%)
# Progress: 350 out of 690 (50%)
# Progress: 360 out of 690 (52%)
# Progress: 370 out of 690 (53%)
# Progress: 380 out of 690 (55%)
# Progress: 390 out of 690 (56%)
# Progress: 400 out of 690 (57%)
# Progress: 410 out of 690 (59%)
# Progress: 420 out of 690 (60%)
# Progress: 430 out of 690 (62%)
# Progress: 440 out of 690 (63%)
# Progress: 450 out of 690 (65%)
# Progress: 460 out of 690 (66%)
# Progress: 470 out of 690 (68%)
# Progress: 480 out of 690 (69%)
# Progress: 490 out of 690 (71%)
# Progress: 500 out of 690 (72%)
# Progress: 510 out of 690 (73%)
# Progress: 520 out of 690 (75%)
# Progress: 530 out of 690 (76%)
# Progress: 540 out of 690 (78%)
# Progress: 550 out of 690 (79%)
# Progress: 560 out of 690 (81%)
# Progress: 570 out of 690 (82%)
# Progress: 580 out of 690 (84%)
# Progress: 590 out of 690 (85%)
# Progress: 600 out of 690 (86%)
# Progress: 610 out of 690 (88%)
# Progress: 620 out of 690 (89%)
# Progress: 630 out of 690 (91%)
# Progress: 640 out of 690 (92%)
# Progress: 650 out of 690 (94%)
# Progress: 660 out of 690 (95%)
# Progress: 670 out of 690 (97%)
# Progress: 680 out of 690 (98%)
# Progress: 690 out of 690 (100%)
# Processed a total of 690 batches.

# %%
df_tracks_enriched = pd.DataFrame(tracks_enriched)
df_tracks_enriched
# Out:
#                           spotify_track_uri                track_id  \
# 0      spotify:track:2wG1R0uDFwyobcWzVssC1J  2wG1R0uDFwyobcWzVssC1J
# 1      spotify:track:2s9BO8c0co0PmgBiUoTT17  2s9BO8c0co0PmgBiUoTT17
# 2      spotify:track:3BDnZJC9yaj01jtqpyDYzG  3BDnZJC9yaj01jtqpyDYzG
# 3      spotify:track:40bK2uosUmAS92c17n98xd  40bK2uosUmAS92c17n98xd
# 4      spotify:track:2PIWldP9oUhb9iqe3EJh1e  2PIWldP9oUhb9iqe3EJh1e
# ...                                     ...                     ...
# 34484  spotify:track:1n108NGnovKSwv2z0J9Vmw  1n108NGnovKSwv2z0J9Vmw
# 34485  spotify:track:5QbWc5ipIn02XePjT0Tvaf  5QbWc5ipIn02XePjT0Tvaf
# 34486  spotify:track:1xHexNjWpStUnoFCqNLanp  1xHexNjWpStUnoFCqNLanp
# 34487  spotify:track:2bQ9UIx9KQkOybSpuTHaL8  2bQ9UIx9KQkOybSpuTHaL8
# 34488  spotify:track:3svsQ3mZLXBkmQMtHUVMR7  3svsQ3mZLXBkmQMtHUVMR7
#
#                     artist_id  \
# 0      5wbf52LA6kcaboHSN6NEF1
# 1      7rXMvXRnWHaSwnVvPeUUfw
# 2      3qvcCP2J0fWi0m0uQDUf6r
# 3      3qvcCP2J0fWi0m0uQDUf6r
# 4      1nca3OA1kKCpP6aPJcBL92
# ...                       ...
# 34484  53XhwfbYqKCa1cC15pYq2q
# 34485  7gOdHgIoIKoe4i9Tta6qdD
# 34486  3h7RaVXBvdSNa7LXQtVYqH
# 34487  5Pwc4xIPtQLFEnJriah9YJ
# 34488  6tw6EpC9RgmSRZiZg0n22t
#
#                                          album_cover_url
# 0      https://i.scdn.co/image/ab67616d0000b27380dadd...
# 1      https://i.scdn.co/image/ab67616d0000b273ea1781...
# 2      https://i.scdn.co/image/ab67616d0000b273e70918...
# 3      https://i.scdn.co/image/ab67616d0000b273d393a0...
# 4      https://i.scdn.co/image/ab67616d0000b2733c7178...
# ...                                                  ...
# 34484  https://i.scdn.co/image/ab67616d0000b273dee648...
# 34485  https://i.scdn.co/image/ab67616d0000b27338f63e...
# 34486  https://i.scdn.co/image/ab67616d0000b2737027fe...
# 34487  https://i.scdn.co/image/ab67616d0000b2734c4052...
# 34488  https://i.scdn.co/image/ab67616d0000b27363b166...
#
# [34489 rows x 4 columns]

# %% [markdown]
# Ok, so the last enriching step is to add the *artist's genre* on the dataset.
#
# Considering that I already have every `artist_id` from the dataset on the *tracks* DataFrame, I just need to unify them exactly the same way as I did with the tracks.
#
# For the same reason, it is natural to think that most part of my musical history is based on a small set of artists/bands, and just a few artists are present only once on the dataset (probably from LoFi playlists with weird names).
#
# The same logic is applied here, as we also have the [Get Several Artists](https://developer.spotify.com/documentation/web-api/reference/get-multiple-artists) endpoint, so I can group them all in batches and then make the request.

# %%
artists_unique = df_tracks_enriched['artist_id'].drop_duplicates()
unique_artist_ids = artists_unique.tolist()

artist_id_batches = []
for i in range(0, len(unique_artist_ids), batch_size):
    artist_id_batches.append(unique_artist_ids[i:i+batch_size])

print('Batches:', len(artist_id_batches))
# Out:
# Batches: 190

# %% [markdown]
# The `genre` field from Spotify can have multiple values, for instance, one band can be considered as *Hard Rock* and *Classic Rock* at once, like AC/DC. For the extent of this work, I will only consider the first **genre** available as the "most important" one.
#
# This can be polemic, as one artist/band can be known for a certain genre for most of people, but Spotify can put the first genre anything else. I don't exactly know at this point how much this will impact on the analysis, but I will leave this simple solution and see what happens later.
#
# Also, another data info available here is the artist image URL, so I will extract is as well to be used on the visualizations.

# %%
artists_enriched = []
counter = 0
request_delay = 0.25 # Delay (in seconds) between requests to avoid API rate limitation

for batch in artist_id_batches:
    artists = sp.artists(batch)['artists']
    
    for artist in artists:

        # Check if there are genres (handle cases where it might be empty)
        artist_genre = artist['genres'][0] if artist['genres'] else None
        artist_image_url = artist['images'][0]['url'] if artist['images'] else None
        
        artists_enriched.append({
            'artist_id': artist['id'],
            'artist_genre': artist_genre,
            'artist_image_url': artist_image_url
        })
        
    # Counting and printing for progress tracking
    counter += 1
    
    if counter % 10 == 0:
        print(f'Progress: {counter} out of {len(artist_id_batches)} ({int(counter / len(artist_id_batches) * 100)}%)')
    
    time.sleep(request_delay)

print(f'Processed a total of {counter} batches.')
# Out:
# Progress: 10 out of 190 (5%)
# Progress: 20 out of 190 (10%)
# Progress: 30 out of 190 (15%)
# Progress: 40 out of 190 (21%)
# Progress: 50 out of 190 (26%)
# Progress: 60 out of 190 (31%)
# Progress: 70 out of 190 (36%)
# Progress: 80 out of 190 (42%)
# Progress: 90 out of 190 (47%)
# Progress: 100 out of 190 (52%)
# Progress: 110 out of 190 (57%)
# Progress: 120 out of 190 (63%)
# Progress: 130 out of 190 (68%)
# Progress: 140 out of 190 (73%)
# Progress: 150 out of 190 (78%)
# Progress: 160 out of 190 (84%)
# Progress: 170 out of 190 (89%)
# Progress: 180 out of 190 (94%)
# Progress: 190 out of 190 (100%)
# Processed a total of 190 batches.

# %%
df_artists_enriched = pd.DataFrame(artists_enriched)
df_artists_enriched.sample(10)
# Out:
#                    artist_id  artist_genre  \
# 1993  0vg08N1z9G9LrGLkG1nNDS         lo-fi
# 8219  7wbkl3zgDZEoZer357mVIw   bedroom pop
# 1006  50TqpjP2iRI4hR1wCfVj3w     reggaeton
# 1452  5sUrlPAHlS9NEirDB8SEbF     latin pop
# 1073  4g3JlT9j18DeWH7gr1uF6L     metalcore
# 353   5hgOjk7FGUwJvo1J3oDK9R  dark ambient
# 4948  6kndrupH2JaLYqh1wBKGar          None
# 4977  1VBflYyxBhnDc9uVib98rw          None
# 3403  7ChbI909duz2evHDqsYsSa          None
# 3735  6JL8zeS1NmiOftqZTRgdTz          None
#
#                                        artist_image_url
# 1993  https://i.scdn.co/image/ab6761610000e5eb71ee25...
# 8219  https://i.scdn.co/image/ab6761610000e5eb710f70...
# 1006  https://i.scdn.co/image/ab6761610000e5ebee235a...
# 1452  https://i.scdn.co/image/ab6761610000e5eb8f09f1...
# 1073  https://i.scdn.co/image/ab6761610000e5ebeec36c...
# 353   https://i.scdn.co/image/ab6761610000e5eb57a1db...
# 4948  https://i.scdn.co/image/ab6761610000e5eb9ca6be...
# 4977  https://i.scdn.co/image/ab6761610000e5ebc66438...
# 3403  https://i.scdn.co/image/ab6761610000e5ebf828dd...
# 3735  https://i.scdn.co/image/ab6761610000e5eb365984...

# %% [markdown]
# Having both DataFrames already done with the intended fields added, *now we are two **JOINs** away from the objective*.

# %%
df_enriched = df_tracks_enriched.merge(
    df_artists_enriched,
    how='left',
    on='artist_id'
)

df_enriched.sample(10)
# Out:
#                           spotify_track_uri                track_id  \
# 6559   spotify:track:7eQHxigpuDJjCG50JyzU8v  7eQHxigpuDJjCG50JyzU8v
# 4932   spotify:track:0XRlRULMnFbsm9EhJDHGYW  0XRlRULMnFbsm9EhJDHGYW
# 1776   spotify:track:2Q0z8XDKkmk5NDprCwE6FF  2Q0z8XDKkmk5NDprCwE6FF
# 32024  spotify:track:531t4BCKZCGCcOine3oGkc  531t4BCKZCGCcOine3oGkc
# 9321   spotify:track:2EPi4anyxVjKTcJwPtntjM  2EPi4anyxVjKTcJwPtntjM
# 15829  spotify:track:6ho0GyrWZN3mhi9zVRW7xi  6ho0GyrWZN3mhi9zVRW7xi
# 31987  spotify:track:1ryLj8yxVclPISoSQ1gL6w  1ryLj8yxVclPISoSQ1gL6w
# 33572  spotify:track:01MqjMMr7HAbGCSmpXPOlc  01MqjMMr7HAbGCSmpXPOlc
# 19284  spotify:track:7Ft93N7aXgfVBgw34LpuiF  7Ft93N7aXgfVBgw34LpuiF
# 1672   spotify:track:6hwQ69v7VbPhTTR2fOtYX7  6hwQ69v7VbPhTTR2fOtYX7
#
#                     artist_id  \
# 6559   1bqxdqvUtPWZri43cKHac8
# 4932   3qm84nBOXUEQ2vnTfUTTFC
# 1776   6xTk3EK5T9UzudENVvu9YB
# 32024  4l9ufn9GC6LLYXvIanDlLd
# 9321   4S2yOnmsWW97dT87yVoaSZ
# 15829  1VJ0briNOlXRtJUAzoUJdt
# 31987  7cU3dIRkY6xry3D6GYqeOg
# 33572  0q74f5UdR3j14Lis4AKKxq
# 19284  6zXHaJc2ZqAmSyxT606ccM
# 1672   5LfGQac0EIXyAN8aUwmNAQ
#
#                                          album_cover_url artist_genre  \
# 6559   https://i.scdn.co/image/ab67616d0000b2734bb6dc...         None
# 4932   https://i.scdn.co/image/ab67616d0000b273d2c9d6...         rock
# 1776   https://i.scdn.co/image/ab67616d0000b2732fe235...         punk
# 32024  https://i.scdn.co/image/ab67616d0000b273e5d41c...   skate punk
# 9321   https://i.scdn.co/image/ab67616d0000b273b00c51...         punk
# 15829  https://i.scdn.co/image/ab67616d0000b2739367c1...   tech house
# 31987  https://i.scdn.co/image/ab67616d0000b273bda8f6...         None
# 33572  https://i.scdn.co/image/ab67616d0000b273de5f1c...     pop punk
# 19284  https://i.scdn.co/image/ab67616d0000b2737f73b5...   skate punk
# 1672   https://i.scdn.co/image/ab67616d0000b2732d4c59...         punk
#
#                                         artist_image_url
# 6559   https://i.scdn.co/image/ab6761610000e5eb23e614...
# 4932   https://i.scdn.co/image/ab6761610000e5eb50defa...
# 1776   https://i.scdn.co/image/ab6761610000e5eb9ef133...
# 32024  https://i.scdn.co/image/ab6761610000e5eb8a3907...
# 9321   https://i.scdn.co/image/ab6772690000c46cddcf65...
# 15829  https://i.scdn.co/image/ab6761610000e5ebcd3fb8...
# 31987  https://i.scdn.co/image/ab6761610000e5eb951bd4...
# 33572  https://i.scdn.co/image/ab6761610000e5ebf1310b...
# 19284  https://i.scdn.co/image/a9d338fd0941e37f58f605...
# 1672   https://i.scdn.co/image/ab6761610000e5eb580938...

# %% [markdown]
# *Quick note:* I am using `sample` instead of `head` or `tail` just to make the results more interesting when taking a look at the dataset (and avoid judgement - or not).

# %%
tracks_history_enriched = tracks_history.merge(
    df_enriched,
    how='left',
    on='spotify_track_uri'
)

tracks_history_enriched.sample(10)
# Out:
#               timestamp_play                                       platform  \
# 15226   2022-10-10T09:44:45Z        Android OS 12 API 31 (Xiaomi, M2101K6G)
# 105161  2019-01-23T02:01:06Z                               Linux [x86-64 0]
# 56625   2021-08-22T04:44:04Z        Android OS 11 API 30 (Xiaomi, M2101K6G)
# 103539  2018-12-07T15:38:02Z  Partner public_js-sdk harmony-chrome.71-linux
# 35530   2017-02-17T13:47:40Z                   Windows 10 (10.0.14393; x64)
# 39526   2017-04-13T20:44:33Z   Android OS 7.0 API 24 (motorola, Moto G (4))
# 27329   2023-04-17T18:22:24Z                                            osx
# 9266    2022-06-19T18:33:39Z                            OS X 12.4.0 [arm 2]
# 43929   2017-05-16T15:13:07Z   Android OS 7.0 API 24 (motorola, Moto G (4))
# 81965   2020-04-14T18:46:31Z                           OS X 10.15.4 [x86 8]
#
#         ms_played                                         track_name  \
# 15226      259158    Just a Gigolo / I Ain't Got Nobody - 45 Version
# 105161     216226                           Desde Quando Você Se Foi
# 56625      225188        No More Sad Songs (feat. Machine Gun Kelly)
# 103539      13436                         I Write Sins Not Tragedies
# 35530      314702                      No Sleep Til Cleveland - Live
# 39526       93121                                         912 Passos
# 27329      100383  Darker Than The Light That Never Bleeds - Ches...
# 9266       101863                                     Cigarette Duet
# 43929        1290                                         Superbeast
# 81965      244364                                      Fora da Regra
#
#                 artist_name  \
# 15226        David Lee Roth
# 105161               Fresno
# 56625            Little Mix
# 103539  Panic! At The Disco
# 35530      Prophets Of Rage
# 39526             Dead Fish
# 27329           Linkin Park
# 9266       Princess Chelsea
# 43929            Rob Zombie
# 81965           Perna Leiga
#
#                                                album_name  \
# 15226   Just a Gigolo/I Ain't Got Nobody (45 Version) ...
# 105161                                           Redenção
# 56625                                          Glory Days
# 103539                        A Fever You Can't Sweat Out
# 35530                              No Sleep Til Cleveland
# 39526                                             Vitória
# 27329             Darker Than The Light That Never Bleeds
# 9266                                     Lil' Golden Book
# 43929                                    Hellbilly Deluxe
# 81965                                          Soca Porva
#
#                            spotify_track_uri reason_start reason_end  \
# 15226   spotify:track:0QcIphdyZIVgFvW7ijEiPX    trackdone  trackdone
# 105161  spotify:track:3Xx8DDgvddsYPnxTH2LXsd    trackdone  trackdone
# 56625   spotify:track:0U372D2pbraSnrTFxSYlNj    trackdone  trackdone
# 103539  spotify:track:5cY8y2XgOfkAh4kSWLFKkz      playbtn    endplay
# 35530   spotify:track:6nfeBDDUAYqcjvIQnERl3p    trackdone        NaN
# 39526   spotify:track:3RDZTFpR9yUQK5i7388iDf       fwdbtn        NaN
# 27329   spotify:track:7FBaqIBcIWVh0bAWlaQaGa    trackdone    endplay
# 9266    spotify:track:5zZt5BzzSrUXwytlRatvc2    trackdone     fwdbtn
# 43929   spotify:track:2lJvciTEU834w2Yl7VVueJ       fwdbtn        NaN
# 81965   spotify:track:7CCeWIg1hK68RU5Wm6Ng5T    trackdone  trackdone
#
#                       track_id               artist_id  \
# 15226   0QcIphdyZIVgFvW7ijEiPX  0KyCXNSa7ZMb5LydfKbLG3
# 105161  3Xx8DDgvddsYPnxTH2LXsd  2sFXe6NbmT3k7Qy4N8fE7f
# 56625   0U372D2pbraSnrTFxSYlNj  3e7awlrlDSwF3iM0WBjGMp
# 103539  5cY8y2XgOfkAh4kSWLFKkz  20JZFwl6HVl6yg8a4H3ZqK
# 35530   6nfeBDDUAYqcjvIQnERl3p  1fSzW5cXBmquli5laFnoGY
# 39526   3RDZTFpR9yUQK5i7388iDf  7Lvg39k5XgXevGR767ikYI
# 27329   7FBaqIBcIWVh0bAWlaQaGa  6XyY86QOPPrYVGvF9ch6wz
# 9266    5zZt5BzzSrUXwytlRatvc2  6SrA4711bML5NvPO13Tr6t
# 43929   2lJvciTEU834w2Yl7VVueJ  3HVdAiMNjYrQIKlOGxoGh5
# 81965   7CCeWIg1hK68RU5Wm6Ng5T  4xadLLBCKTecYQRPoUhAQ0
#
#                                           album_cover_url      artist_genre  \
# 15226   https://i.scdn.co/image/ab67616d0000b273101502...        glam metal
# 105161  https://i.scdn.co/image/ab67616d0000b273a5c306...           emocore
# 56625   https://i.scdn.co/image/ab67616d0000b2733042c5...              None
# 103539  https://i.scdn.co/image/ab67616d0000b273e8b923...               emo
# 35530   https://i.scdn.co/image/ab67616d0000b2731ac9ce...         rap metal
# 39526   https://i.scdn.co/image/ab67616d0000b273e17de8...    brazilian rock
# 27329   https://i.scdn.co/image/ab67616d0000b273f25331...          nu metal
# 9266    https://i.scdn.co/image/ab67616d0000b27368a2b4...       baroque pop
# 43929   https://i.scdn.co/image/ab67616d0000b273ae17cb...  industrial metal
# 81965   https://i.scdn.co/image/ab67616d0000b273a058a9...    brazilian rock
#
#                                          artist_image_url
# 15226   https://i.scdn.co/image/ab6761610000e5eb7b3b79...
# 105161  https://i.scdn.co/image/ab6761610000e5eba4e56a...
# 56625   https://i.scdn.co/image/ab6761610000e5eb08cd53...
# 103539  https://i.scdn.co/image/ab6761610000e5ebb256ae...
# 35530   https://i.scdn.co/image/ab6761610000e5eb0f23cf...
# 39526   https://i.scdn.co/image/ab6761610000e5ebdcde01...
# 27329   https://i.scdn.co/image/ab6761610000e5ebc7e6bd...
# 9266    https://i.scdn.co/image/ab6761610000e5eba23699...
# 43929   https://i.scdn.co/image/ab6761610000e5eb40a6cf...
# 81965   https://i.scdn.co/image/ab6761610000e5eb29bd79...

# %% [markdown]
# Now, my last concern is about the `platform` field available on the dataset. As I am making an overview analysis on my musical taste, I am not interested on know which version of Android or Windows I was using when I was listening to certain track. I just want to know if it was on a PC, my phone or any other device, in general terms.
#
# So, now it's time to take care of this information. First I created a mapping to normalize the names, and then applied it to the `platform` field, creating the `simplified_platform` column. Then, I dropped the original `platform` column and renamed the new column as platform, just to simplify the dataset (confusing?).
#
# *Note:* also, as a matter of Privacy and Security, I dropped the original `platform` column from the dataset, as it will be available publicly on Tableau Public. Not that anyone is interested in my devices and their versions, but I prefer not taking the risk.

# %%
tracks_history_enriched.groupby('platform')['spotify_track_uri'].count().sort_values(ascending=False)
# Out:
# platform
# Android OS 7.0 API 24 (motorola, Moto G (4))                 19275
# osx                                                          17941
# Android OS 9 API 28 (Xiaomi, Redmi Note 5)                   16788
# Android OS 11 API 30 (Xiaomi, M2101K6G)                      13137
# Linux [x86-64 0]                                             10031
#                                                              ...
# web_player windows 10;chrome 74.0.3729.169;desktop               1
# web_player windows 10;chrome 75.0.3770.90;desktop                1
# web_player windows 10;chrome 88.0.4324.104;desktop               1
# web_player windows 10;chrome 89.0.4389.90;desktop                1
# web_player osx 10.15.5;microsoft edge 83.0.478.58;desktop        1
# Name: spotify_track_uri, Length: 103, dtype: int64

# %%
platform_mapping = {
    'android': 'Android',
    'osx': 'macOS',
    'os x': 'macOS',
    'windows': 'Windows',
    'web_player': 'Web Browser',
    'linux': 'Linux',
    'ps4': 'PS4',
    'xbox': 'Xbox',
    'tv': 'Smart TV',
    'cast': 'Cast'
}

# Function to simplify platform names
def simplify_platform(platform):
    for key, value in platform_mapping.items():
        if key in platform.lower():
            return value

    return 'Others'

# Apply the simplify_platform function to the "platform" column
tracks_history_enriched['simplified_platform'] = tracks_history_enriched['platform'].apply(simplify_platform)

# Removing the complete platform info for security reasons
tracks_history_enriched.drop(columns=['platform'], inplace=True)
tracks_history_enriched.rename(columns={'simplified_platform': 'platform'}, inplace=True)

tracks_history_enriched.groupby('platform')['track_id'].count().sort_values(ascending=False)
# Out:
# platform
# Android        71015
# macOS          67018
# Windows        38019
# Linux          10046
# PS4             1484
# Cast             909
# Xbox             544
# Others           347
# Smart TV         291
# Web Browser      107
# Name: track_id, dtype: int64

# %%
len(tracks_history_enriched)
# Out:
# 189780

# %%
unique_album_covers = tracks_history_enriched.groupby(['artist_name', 'album_name'], as_index=False)[['album_cover_url']].first()

tracks_history_enriched = tracks_history_enriched.merge(unique_album_covers, how='left', on=['artist_name', 'album_name'], suffixes=('_1', '_2'))
tracks_history_enriched.drop(columns='album_cover_url_1', inplace=True)
tracks_history_enriched.rename(columns={'album_cover_url_2': 'album_cover_url'}, inplace=True)

tracks_history_enriched.sample(10)
# Out:
#               timestamp_play  ms_played                 track_name  \
# 186053  2018-01-04T13:34:19Z     153600  I'm Shipping Up To Boston
# 171960  2020-11-07T16:43:20Z     205280              Numb / Encore
# 107113  2019-03-12T22:24:41Z      74288                    Só você
# 48007   2017-07-08T02:33:25Z     268426         Losing My Religion
# 2056    2022-02-21T21:58:02Z       5222                Crazy Nando
# 42638   2017-05-07T22:39:39Z     281332                  The Black
# 118572  2015-05-15T23:48:04Z       2959                 Trap Queen
# 53733   2021-07-08T12:00:09Z     171998           Agora é Tudo Meu
# 167269  2020-08-24T00:23:17Z     188849                 No Diggity
# 5195    2022-04-14T22:41:58Z     220905           Whatchu Thinkin'
#
#                   artist_name          album_name  \
# 186053       Dropkick Murphys  The Warrior's Code
# 171960                  JAY-Z    Collision Course
# 107113                   Hori    Hori Versão + Fã
# 48007                  R.E.M.         Out Of Time
# 2056          The Black Mamba         Crazy Nando
# 42638       Asking Alexandria           The Black
# 118572              Fetty Wap          Trap Queen
# 53733                  DENNIS    Agora é Tudo Meu
# 167269         Campsite Dream          No Diggity
# 5195    Red Hot Chili Peppers      Unlimited Love
#
#                            spotify_track_uri reason_start reason_end  \
# 186053  spotify:track:7rSERmjAT38lC5QhJ8hnQc    trackdone        NaN
# 171960  spotify:track:7dyluIqv7QYVTXXZiMWPHW    trackdone  trackdone
# 107113  spotify:track:2OE0yPXbN6ejT5cJSlKgwz    trackdone     fwdbtn
# 48007   spotify:track:2wVXSc0IrQVodHESUxVUJA    trackdone        NaN
# 2056    spotify:track:5Im0tMPrcyFbbTDMdUaspx     clickrow    endplay
# 42638   spotify:track:4ORXSxr4tV5H6gH5KHAiAh    trackdone        NaN
# 118572  spotify:track:3twQx3psUMJKj4wna5d1zU       fwdbtn     fwdbtn
# 53733   spotify:track:5yH8pYxNckOU1cxfPsMIaz    trackdone  trackdone
# 167269  spotify:track:79T9m6YkRCgP0955CE4UCd    trackdone  trackdone
# 5195    spotify:track:37o0LxdGxiF3chjxjwJwBD    trackdone  trackdone
#
#                       track_id               artist_id    artist_genre  \
# 186053  7rSERmjAT38lC5QhJ8hnQc  7w9jdhcgHNdiPeNPUoFSlx     celtic rock
# 171960  7dyluIqv7QYVTXXZiMWPHW  3nFkdlSjzX9mRTtwJOzDYB         hip hop
# 107113  2OE0yPXbN6ejT5cJSlKgwz  4cn93QHq3HY7wAgnV7bSZ9         emocore
# 48007   2wVXSc0IrQVodHESUxVUJA  4KWTAlx2RvbpseOGMEmROg      jangle pop
# 2056    5Im0tMPrcyFbbTDMdUaspx  2huzXUiBGRUJ8iRFD4NHc7            None
# 42638   4ORXSxr4tV5H6gH5KHAiAh  1caBfBEapzw8z2Qz9q0OaQ       metalcore
# 118572  3twQx3psUMJKj4wna5d1zU  6PXS4YHDkKvl1wkIl4V8DL            None
# 53733   5yH8pYxNckOU1cxfPsMIaz  6xlRSRMLgZbsSNd0BMobwy            funk
# 167269  79T9m6YkRCgP0955CE4UCd  69VkQLf4DH7GJ68BCDOPKL  tropical house
# 5195    37o0LxdGxiF3chjxjwJwBD  0L8ExT028jH3ddEcZwqJJ5       funk rock
#
#                                          artist_image_url platform  \
# 186053  https://i.scdn.co/image/ab6761610000e5eb2b3032...    Linux
# 171960  https://i.scdn.co/image/ab6761610000e5ebc75afc...  Android
# 107113  https://i.scdn.co/image/ab67616d0000b273462eac...  Android
# 48007   https://i.scdn.co/image/ab6761610000e5eb6334ab...  Windows
# 2056    https://i.scdn.co/image/ab6761610000e5eb5e8c20...  Android
# 42638   https://i.scdn.co/image/ab6761610000e5ebd07f0b...  Android
# 118572  https://i.scdn.co/image/ab6761610000e5eb8ffb1b...  Windows
# 53733   https://i.scdn.co/image/ab6761610000e5eb84e963...  Android
# 167269  https://i.scdn.co/image/ab6761610000e5eb998363...    macOS
# 5195    https://i.scdn.co/image/ab6761610000e5ebc33cc1...  Android
#
#                                           album_cover_url
# 186053  https://i.scdn.co/image/ab67616d0000b273030915...
# 171960  https://i.scdn.co/image/ab67616d0000b273d3acd0...
# 107113  https://i.scdn.co/image/ab67616d0000b273462eac...
# 48007   https://i.scdn.co/image/ab67616d0000b273e2dd4e...
# 2056    https://i.scdn.co/image/ab67616d0000b27344c62e...
# 42638   https://i.scdn.co/image/ab67616d0000b27309c75d...
# 118572  https://i.scdn.co/image/ab67616d0000b2737f2d80...
# 53733   https://i.scdn.co/image/ab67616d0000b273a58013...
# 167269  https://i.scdn.co/image/ab67616d0000b273e45756...
# 5195    https://i.scdn.co/image/ab67616d0000b27397a52e...

# %% [markdown]
# Objectives accomplished, now it is time to export the enriched dataset.

# %%
tracks_history_enriched.to_csv('consolidated_spotify_data_2024_enriched.csv', index=False)
print('File saved!')
# Out:
# File saved!
